# %%
import pandas as pd
import numpy as np
import datetime as datetime

# %%
df = pd.read_csv('Data\starbucks.csv', index_col='Date', parse_dates=True)

# %%
df.head()
# Out:
#          Date    Close    Volume
# 0  2015-01-02  38.0061   6906098
# 1  2015-01-05  37.2781  11623796
# 2  2015-01-06  36.9748   7664340
# 3  2015-01-07  37.8848   9732554
# 4  2015-01-08  38.4961  13170548

# %%
# Out:
#   File "<ipython-input-10-51a8476cacaf>", line 1
#     df = (df, index='Date', parse_dates=True)
#                    ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
title = 'starbucks daily stock closing price'
df['Close'].plot(figsize=(16,6), title=title)
